# %%
from langgraph.graph import START, END, StateGraph
from langchain_anthropic import ChatAnthropic
from pydantic import BaseModel, Field
from typing import TypedDict, Annotated
from dotenv import load_dotenv
import operator

load_dotenv()
# Out:
# True

# %%
class EvaluationSchema(BaseModel):
    score: int = Field(description="A score from 1 to 10 evaluating the quality of the essay.", ge=0, le=10)
    feedback: str = Field(description="Detailed feedback on the essay.")

# %%
model = ChatAnthropic(model="claude-haiku-4-5-20251001")
structured_model = model.with_structured_output(EvaluationSchema)

# %%
class EvaluationState(TypedDict):
    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %%
def evaluate_language(state: EvaluationState) -> EvaluationState:
    prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'language_feedback': output.feedback, 'individual_scores': [output.score]}

def evaluate_analysis(state: EvaluationState) -> EvaluationState:
    prompt = f'Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'analysis_feedback': output.feedback, 'individual_scores': [output.score]}

def evaluate_thought(state: EvaluationState) -> EvaluationState:
    prompt = f'Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'clarity_feedback': output.feedback, 'individual_scores': [output.score]}

def overall_feedback(state: EvaluationState) -> EvaluationState:
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state["language_feedback"]} \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of thought feedback - {state["clarity_feedback"]}'
    overall_feedback = model.invoke(prompt).content
    
    avg_score = sum(state.get('individual_scores')) / len(state.get('individual_scores'))

    return {'overall_feedback': overall_feedback, 'avg_score': avg_score}

# %%
graph = StateGraph(EvaluationState)

graph.add_node('evaluate_language', evaluate_language)
graph.add_node('evaluate_analysis', evaluate_analysis)
graph.add_node('evaluate_thought', evaluate_thought)
graph.add_node('overall_feedback', overall_feedback)

graph.add_edge(START, 'evaluate_language')
graph.add_edge(START, 'evaluate_analysis')
graph.add_edge(START, 'evaluate_thought')

graph.add_edge('evaluate_thought', 'overall_feedback')
graph.add_edge('evaluate_analysis', 'overall_feedback')
graph.add_edge('evaluate_language', 'overall_feedback')

graph.add_edge('overall_feedback', END)

workflow = graph.compile()

workflow

# %%
sample_essay = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
initial_state = {'essay': sample_essay}

result = workflow.invoke(initial_state)

# %%
result
# Out:
# {'essay': "India in the Age of AI\nAs the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.\n\nIndia's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.\n\nOne of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.\n\nHowever, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.\n\nAnother pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.\n\nTo harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.\n\nIndia’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.\n\nIn conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society.",
#  'language_feedback': 'This is a well-structured and comprehensive essay on India\'s position in the AI landscape. Here are the strengths and areas for improvement:\n\n**Strengths:**\n1. **Clear Organization**: The essay follows a logical progression—introduction, India\'s strengths, applications, challenges, solutions, and conclusion. The flow is coherent and easy to follow.\n2. **Balanced Analysis**: The author effectively presents both opportunities (skilled workforce, startup ecosystem, AI applications) and challenges (digital divide, job displacement, data privacy), showing critical thinking.\n3. **Specific Examples**: The essay uses concrete instances (IITs, IIITs, TCS, Infosys, applications in healthcare and agriculture) that strengthen the arguments.\n4. **Professional Tone**: The language is formal and appropriate for an academic essay, with effective use of transitional phrases like "However," "Chief among them," and "To harness."\n5. **Strong Conclusion**: The final paragraph effectively ties the arguments together and emphasizes the human-centered approach to AI.\n\n**Areas for Improvement:**\n1. **Minor Grammatical Issues**: While generally strong, there are a few minor areas:\n   - "As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge..." - The em-dash usage is acceptable but slightly informal for academic writing.\n   \n2. **Redundancy**: Some ideas are slightly repetitive. For instance, the challenges of digital divide and job displacement are introduced but could benefit from more specific statistical support or solutions.\n\n3. **Depth of Solutions**: While the essay identifies problems well, the solutions section (multi-stakeholder approach) is somewhat general. More specific policy recommendations or case studies would strengthen this section.\n\n4. **Data Citation**: The essay mentions "5 million STEM graduates annually" and references the "National AI Strategy (AI for All)" from 2020, but these could benefit from explicit citations for academic rigor.\n\n5. **Word Choice Precision**: Phrases like "riddled with challenges" are slightly colloquial for an academic essay. More formal alternatives like "fraught with challenges" or "beset by challenges" might be more appropriate.\n\n**Overall Assessment**: This is a mature, well-reasoned essay that demonstrates solid understanding of the topic. The language is generally clear and professional, with good vocabulary and sentence variety. It would benefit from deeper research support and more specific recommendations, but it successfully presents a balanced argument about India\'s AI future.',
#  'analysis_feedback': 'This essay provides a well-structured overview of India\'s AI landscape but falls short in depth of analysis. Here are the key strengths and weaknesses:\n\n**Strengths:**\n1. Clear organizational structure with well-defined sections covering strengths, opportunities, challenges, and solutions\n2. Balanced perspective acknowledging both opportunities and risks\n3. Relevant examples across multiple sectors (agriculture, healthcare, education, governance)\n4. Appropriate acknowledgment of India\'s demographic advantages\n5. Recognition of the multi-stakeholder approach needed for responsible AI development\n\n**Weaknesses in Depth of Analysis:**\n\n1. **Superficial Treatment of Complex Issues**: The challenges section (digital divide, job displacement, data privacy) is mentioned but not deeply explored. For instance, the essay doesn\'t quantify the magnitude of the digital divide, provide statistics on potential job displacement, or discuss specific sectors most vulnerable to automation.\n\n2. **Lack of Critical Examination**: The essay doesn\'t critically examine India\'s actual AI readiness. What is India\'s current ranking in global AI competitiveness? How does India\'s AI development compare to China, the US, or other Asian nations?\n\n3. **Missing Data and Evidence**: While institutions and companies are mentioned, the essay lacks concrete metrics—How much R&D spending is India investing in AI compared to global leaders? What is the current state of adoption rates?\n\n4. **Vague Policy Recommendations**: The suggestion for "multi-stakeholder approach" and "open datasets" is generic. The essay doesn\'t provide specific policy frameworks, timelines, or innovative mechanisms India could implement.\n\n5. **Underdeveloped Solutions**: The gap between identifying problems and proposing solutions is significant. For example, the essay identifies the digital divide but doesn\'t propose concrete strategies beyond vague mentions of collaboration.\n\n6. **Limited Discussion of Ethical Frameworks**: While data privacy and bias are mentioned, there\'s no exploration of specific ethical challenges like algorithmic bias in Indian contexts, or how existing cultural and social systems might interact with AI biases.\n\n7. **Absence of Counterarguments**: The essay doesn\'t engage with skeptical perspectives or potential downsides, such as whether India\'s focus on AI might divert resources from addressing basic infrastructure needs.\n\n8. **Weak Connection Between Sections**: The discussion of demographic dividend in the conclusion feels disconnected from earlier analysis and isn\'t integrated into the overall argument coherently.\n\n**Overall Assessment:**\nThis reads more like an introductory essay or policy briefing rather than a deep analytical piece. It covers the right topics but treats them at a surface level. To improve, the essay would benefit from: specific case studies, comparative analysis with other nations, quantified data, deeper exploration of proposed solutions, and engagement with counterarguments or trade-offs.',
#  'clarity_feedback': 'This essay demonstrates strong clarity of thought with well-organized arguments and coherent structure. Here are the key strengths and areas for consideration:\n\n**Strengths:**\n1. **Clear thesis and scope**: The introduction effectively establishes India\'s position at a critical juncture regarding AI adoption, setting up a balanced exploration of opportunities and challenges.\n2. **Logical organization**: The essay follows a clear progression—establishing India\'s strengths, showcasing applications, addressing challenges, proposing solutions, and concluding with a vision.\n3. **Balanced perspective**: The author presents both optimistic opportunities (agriculture, healthcare, education) and serious concerns (digital divide, job displacement, privacy), avoiding oversimplification.\n4. **Concrete examples**: References to specific institutions (IITs, IISc), companies (TCS, Infosys), and government initiatives (AI for All strategy) ground the argument in reality.\n5. **Interconnected ideas**: The essay effectively links India\'s demographic dividend to AI adoption and frames it within broader socio-economic development.\n\n**Areas for improvement:**\n1. **Specificity in solutions**: While the essay identifies challenges well, the proposed solutions (multi-stakeholder approach, open datasets) are somewhat generic and lack concrete actionable steps or examples.\n2. **Data and statistics**: Beyond mentioning "5 million STEM graduates," the essay could strengthen claims with more specific data on India\'s current AI market size, funding, or comparative metrics with other nations.\n3. **Nuance on job displacement**: While mentioned, the discussion on automation\'s impact could explore potential job creation in AI-related fields or comparative impact across sectors.\n4. **Global context**: Limited comparison with how other nations (China, US, Southeast Asian countries) are approaching similar challenges, which would add depth.\n\n**Overall Assessment:**\nThe essay demonstrates clear, coherent thinking with a well-defined argument structure. It successfully navigates complex themes while remaining accessible. The writing is professional and the logical flow is easy to follow, making it an above-average piece on a nuanced topic.',
#  'overall_feedback': '# Summarized Feedback on India\'s AI Essay\n\n## Overall Assessment\nThis is a **well-structured, above-average essay** that demonstrates clear thinking and balanced analysis. It effectively presents India\'s AI landscape with good organization and professional tone, but lacks the depth and specificity needed for advanced academic work.\n\n---\n\n## Key Strengths\n- ✅ **Clear organization and logical flow** across all sections\n- ✅ **Balanced perspective** acknowledging both opportunities and challenges\n- ✅ **Concrete examples** (IITs, TCS, Infosys, sector applications)\n- ✅ **Professional language** with appropriate academic tone\n- ✅ **Coherent thesis** connecting India\'s position to broader socio-economic context\n\n---\n\n## Primary Areas for Development\n\n### 1. **Depth of Analysis**\n- Challenges (digital divide, job displacement, data privacy) are identified but not thoroughly examined\n- Missing comparative analysis with other nations (China, US, Southeast Asia)\n- No critical examination of India\'s actual AI readiness or competitive ranking\n- Lacks exploration of context-specific challenges like algorithmic bias in Indian systems\n\n### 2. **Evidence and Data Support**\n- Mentions "5 million STEM graduates" but lacks citations\n- Missing quantified metrics on:\n  - Digital divide magnitude\n  - Job displacement statistics by sector\n  - India\'s R&D spending vs. global leaders\n  - Market size and adoption rates\n- References government initiatives without supporting data\n\n### 3. **Solutions Section is Too Generic**\n- "Multi-stakeholder approach" and "open datasets" lack specificity\n- No concrete policy frameworks, timelines, or implementation mechanisms\n- Disconnect between problems identified and solutions proposed\n- Missing case studies or innovative mechanisms for India\'s context\n\n### 4. **Language Refinements Needed**\n- Minor colloquialisms ("riddled with challenges") should be more formal\n- Em-dash usage acceptable but slightly informal for academic writing\n- Some redundancy in presenting overlapping challenges\n\n---\n\n## Recommendations for Improvement\n1. Add specific statistics and citations to strengthen claims\n2. Develop solutions section with actionable recommendations and timelines\n3. Include comparative analysis with other nations\' AI strategies\n4. Explore India-specific ethical frameworks and algorithmic bias concerns\n5. Integrate counterarguments or trade-offs (e.g., AI vs. basic infrastructure needs)\n6. Ground abstract concepts with more case studies\n\n---\n\n## Final Verdict\n**Current Level**: Introductory to intermediate essay with solid fundamentals  \n**Potential**: Can reach advanced analytical level with deeper research, specific data integration, and more nuanced problem-solving approaches.',
#  'individual_scores': [6, 8, 8],
#  'avg_score': 7.333333333333333}
